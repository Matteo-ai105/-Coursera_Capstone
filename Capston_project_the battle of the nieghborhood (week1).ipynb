# %% [markdown]
# Applied Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [raw]
# Now that you have been equipped with the skills and the tools to use location data to explore a geographical location, over the course of two weeks, you will have the opportunity to be as creative as you want and come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve.

# %% [markdown]
# 1) Introduction/ Business Problem

# %% [raw]
# Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.
#
# In Italy, pizza is a typical dish that calls visitors from all over the world. Unfortunatly, pizzerias are increasing in many of the most important Italian cities and find the perfect location for growing the commercial activity can be an hard problem.
# In order to overcome this issue, the idea is to chose the right location by providing data about the income of each Neighborhood in Bologna(Italy) as well as the frequency of pizzerias around the city.

# %% [markdown]
# 2) Data Used

# %% [markdown]
# 2) Data
# Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.

# %% [raw]
# To provide the stakeholders the necessary information I'll be combining the Average income per Neighborhood with Foursquare API to collect competitors on the same neighborhoods.
# Bologna's average income data in publicly available at this website: http://inumeridibolognametropolitana.it/quartieri/reddito-et%C3%A0

# %% [raw]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
#!pip install beautifulsoup4
#!pip install lxml
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 


from IPython.display import display_html
import pandas as pd
import numpy as np
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [raw]
# Upload my Foursquare Client_ID and Client_Secret and Access_Token (For privacy reasons I don't include this in the report) and a LIMIT of 500 in searching.

# %%
CLIENT_ID = '###################################' # your Foursquare ID
CLIENT_SECRET = '#########################################' # your Foursquare Secret
ACCESS_TOKEN = '##########################################' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ###################################
# CLIENT_SECRET:#########################################

# %% [raw]
# Get the latitude and longitude of Bologna for the analysis.

# %%
address = 'Bologna, BO'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 44.4936714 11.3430347

# %% [raw]
# Then I extracted from Fousquare API the presence of pizzerias in Bologna with a radius of 7.5 km

# %%
search_query = 'pizzeria'
radius = 7500
print(search_query + ' .... OK!')
# Out:
# pizzeria .... OK!

# %% [raw]
# Define the corresponding url

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

# %% [raw]
# Get the results in a json format file

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fcca3b49ff888209502bb9d'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4bfcfc65e529c928f231ba8c',
#     'name': 'Pizzeria Ristorante Scalinatella',
#     'location': {'address': 'Via Caduti di Cefalonia, 5/E',
#      'lat': 44.49525,
#      'lng': 11.34426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49525,
#        'lng': 11.34426}],
#      'distance': 200,
#      'postalCode': '40125',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Caduti di Cefalonia, 5/E',
#       '40125 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4de8c676fa76fd1168a7f79b',
#     'name': 'Trattoria Pizzeria Belle Arti',
#     'location': {'address': 'Via delle Belle Arti, 14',
#      'lat': 44.49780496606923,
#      'lng': 11.349945917825716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49780496606923,
#        'lng': 11.349945917825716}],
#      'distance': 716,
#      'postalCode': '40126',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via delle Belle Arti, 14',
#       '40126 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4bebda0da9900f47b0381840',
#     'name': 'Pizzeria Petroni',
#     'location': {'address': 'Via Petroni 7/b',
#      'lat': 44.49469924095751,
#      'lng': 11.352031230926514,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49469924095751,
#        'lng': 11.352031230926514}],
#      'distance': 723,
#      'postalCode': '40126',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Petroni 7/b', '40126 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c1e6035c4a0ef3b6f1cbd8b',
#     'name': 'Pizzeria da Totò',
#     'location': {'address': 'Via San Rocco 7',
#      'lat': 44.49640345447888,
#      'lng': 11.330180034633623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49640345447888,
#        'lng': 11.330180034633623}],
#      'distance': 1065,
#      'postalCode': '40122',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via San Rocco 7', '40122 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c6d7fa7d5c3a1cdbfa7c52b',
#     'name': 'Ristorante Pizzeria Porta Saragozza',
#     'location': {'address': 'Via Saragozza 71',
#      'lat': 44.49055832487309,
#      'lng': 11.331224846784476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49055832487309,
#        'lng': 11.331224846784476}],
#      'distance': 999,
#      'postalCode': '40123',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Saragozza 71', '40123 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '50a62f8ee4b06c2ca79bd604',
#     'name': 'Pizzeria Nettuno',
#     'location': {'address': 'Via Fossalta 4h',
#      'crossStreet': 'Via Rizzoli',
#      'lat': 44.494960569646075,
#      'lng': 11.343894630276322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.494960569646075,
#        'lng': 11.343894630276322}],
#      'distance': 158,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Fossalta 4h (Via Rizzoli)',
#       'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '5339c0e811d25f69b458d977',
#     'name': 'pizzeria a modo mio',
#     'location': {'address': 'Via Andrea Costa',
#      'lat': 44.494838,
#      'lng': 11.316141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.494838,
#        'lng': 11.316141}],
#      'distance': 2139,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Andrea Costa', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e3d82b7fa76455375b8de0f',
#     'name': 'Pizzeria Da Carlo',
#     'location': {'address': 'Via del Timavo',
#      'crossStreet': 'Via Saffi',
#      'lat': 44.50195744687222,
#      'lng': 11.3189026568757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.50195744687222,
#        'lng': 11.3189026568757}],
#      'distance': 2126,
#      'postalCode': '40133',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via del Timavo (Via Saffi)',
#       '40133 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4cc410e542d1b60c8c521b13',
#     'name': 'Pizzeria al Tavolaccio',
#     'location': {'address': 'Via Andrea Costa 114',
#      'crossStreet': 'Via della Crocetta',
#      'lat': 44.495209514040326,
#      'lng': 11.318463713487812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.495209514040326,
#        'lng': 11.318463713487812}],
#      'distance': 1958,
#      'postalCode': '40134',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Andrea Costa 114 (Via della Crocetta)',
#       '40134 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4cadad6655238cfa0564b3fb',
#     'name': 'Pizzeria Due Torri',
#     'location': {'address': 'Strada Maggiore 3',
#      'lat': 44.49404434994599,
#      'lng': 11.34695543510219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49404434994599,
#        'lng': 11.34695543510219}],
#      'distance': 314,
#      'postalCode': '40125',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Strada Maggiore 3',
#       '40125 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '5d9c72906b85670008db520e',
#     'name': 'L’Antica Pizzeria Da Michele',
#     'location': {'address': 'Piazza S. Martino 3b',
#      'lat': 44.497171,
#      'lng': 11.346353,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.497171,
#        'lng': 11.346353}],
#      'distance': 470,
#      'postalCode': '40126',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza S. Martino 3b',
#       '40126 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4db5c2ec0cb6729b6aabf2c3',
#     'name': "Pizzeria D'asporto Stella",
#     'location': {'address': 'Via Galliera, 12 c',
#      'lat': 44.498382,
#      'lng': 11.3421,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.498382,
#        'lng': 11.3421}],
#      'distance': 529,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Galliera, 12 c', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '533ab0a1498e11c874ef2ffc',
#     'name': 'Pizzeria da Roberto',
#     'location': {'address': 'Via Nazario Sauro 28',
#      'lat': 44.497957,
#      'lng': 11.339596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.497957,
#        'lng': 11.339596}],
#      'distance': 549,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Nazario Sauro 28', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4d91c3b0d7b1236af4e63638',
#     'name': 'Pizzeria Respighi',
#     'location': {'address': 'Via dei castagnoli 6/B',
#      'lat': 44.49627750753935,
#      'lng': 11.34922230299135,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49627750753935,
#        'lng': 11.34922230299135}],
#      'distance': 570,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via dei castagnoli 6/B', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c4eb9149932e21ea14532ce',
#     'name': "Ristorante Pizzeria Rococo'",
#     'location': {'address': 'Via Ferrarese',
#      'lat': 44.513788,
#      'lng': 11.352389,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.513788,
#        'lng': 11.352389}],
#      'distance': 2359,
#      'cc': 'IT',
#      'neighborhood': 'Navile',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Ferrarese', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4f2145b1e4b07fb248d74896',
#     'name': 'Pizzeria Pugliese',
#     'location': {'address': 'Via Petroni 29/A',
#      'lat': 44.49560661431662,
#      'lng': 11.350040459952098,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49560661431662,
#        'lng': 11.350040459952098}],
#      'distance': 596,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Petroni 29/A', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e3ed4e5ae6045423677c320',
#     'name': 'Pizzeria da asporto GM',
#     'location': {'address': 'Via Nosadella 14A',
#      'lat': 44.49220275878906,
#      'lng': 11.33541488647461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49220275878906,
#        'lng': 11.33541488647461}],
#      'distance': 626,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Nosadella 14A', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '51ba0f81498eb59c5e9e25b7',
#     'name': 'Pizzeria GM',
#     'location': {'lat': 44.492209,
#      'lng': 11.335207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.492209,
#        'lng': 11.335207}],
#      'distance': 642,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4ffca8d1e4b07010bfa9c0a2',
#     'name': 'Pizzeria D.O.C',
#     'location': {'lat': 44.497231,
#      'lng': 11.349003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.497231,
#        'lng': 11.349003}],
#      'distance': 617,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c56627b744a0f4753b5c6cb',
#     'name': 'Pizzeria Emilia',
#     'location': {'address': 'Via zamboni 26 E F',
#      'lat': 44.496263,
#      'lng': 11.350578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.496263,
#        'lng': 11.350578}],
#      'distance': 664,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via zamboni 26 E F', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '51dd42db498ec99902ecc04c',
#     'name': 'Pizzeria DOC',
#     'location': {'address': 'Via delle Moline',
#      'lat': 44.497316,
#      'lng': 11.349272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.497316,
#        'lng': 11.349272}],
#      'distance': 640,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Via delle Moline']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4dea06f052b11677f02ff4e4',
#     'name': 'Pizzeria La Livella',
#     'location': {'lat': 44.518228,
#      'lng': 11.324174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.518228,
#        'lng': 11.324174}],
#      'distance': 3116,
#      'cc': 'IT',
#      'neighborhood': 'Navile',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '50bcfa64e4b0073c180fae90',
#     'name': 'pizzeria gli archi',
#     'location': {'lat': 44.499507904052734,
#      'lng': 11.346359252929688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.499507904052734,
#        'lng': 11.346359252929688}],
#      'distance': 701,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '51325aa3e4b0a2e12a780120',
#     'name': 'Pizzeria Il Moro Bologna',
#     'location': {'lat': 44.49912626366037,
#      'lng': 11.342955701742214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49912626366037,
#        'lng': 11.342955701742214}],
#      'distance': 607,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c42123c520fa59391a4caac',
#     'name': "Pizzeria O' Sole Mio",
#     'location': {'lat': 44.487584739424975,
#      'lng': 11.34813791229302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.487584739424975,
#        'lng': 11.34813791229302}],
#      'distance': 789,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c9c5513e9a7ef3ba7843316',
#     'name': 'Pizzeria Pinterrè',
#     'location': {'address': 'Via Giuseppe Mazzini, 170',
#      'lat': 44.48481518599252,
#      'lng': 11.371689533729523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.48481518599252,
#        'lng': 11.371689533729523}],
#      'distance': 2479,
#      'postalCode': '40139',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Giuseppe Mazzini, 170',
#       '40139 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '52fe72bd498efa6404b763e0',
#     'name': 'Pizzeria Naveed',
#     'location': {'address': 'Via Casoni, 2/b',
#      'lat': 44.52041244506836,
#      'lng': 11.360477447509766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.52041244506836,
#        'lng': 11.360477447509766}],
#      'distance': 3283,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Casoni, 2/b', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e1a0dd3d4c062b044f7d335',
#     'name': "Pizzeria d'asporto Mascarella",
#     'location': {'address': 'Via Mascarella 9',
#      'lat': 44.498403196043945,
#      'lng': 11.349477767944336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.498403196043945,
#        'lng': 11.349477767944336}],
#      'distance': 734,
#      'postalCode': '40126',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Mascarella 9', '40126 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '526bfdcc498e90936fa7f084',
#     'name': 'Altero Pizzeria',
#     'location': {'lat': 44.49840796904334,
#      'lng': 11.343638384765152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49840796904334,
#        'lng': 11.343638384765152}],
#      'distance': 529,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4cd5bef276ab721e2b206f6a',
#     'name': 'Pizzeria Ristorante La Brace',
#     'location': {'address': 'Via San Vitale',
#      'lat': 44.49444228484714,
#      'lng': 11.349378576032008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49444228484714,
#        'lng': 11.349378576032008}],
#      'distance': 511,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via San Vitale', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4d851c6e5e70224ba4d91b09',
#     'name': 'Pizzeria Il Sorriso',
#     'location': {'lat': 44.497101420534456,
#      'lng': 11.336588301295857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.497101420534456,
#        'lng': 11.336588301295857}],
#      'distance': 638,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '5984c0fba5a31517f8ac69c1',
#     'name': 'Il Saraceno Ristorante Pizzeria',
#     'location': {'address': 'Via Calcavinazzi, 2',
#      'lat': 44.49549,
#      'lng': 11.34066,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49549,
#        'lng': 11.34066}],
#      'distance': 276,
#      'postalCode': '40121',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Calcavinazzi, 2',
#       '40121 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '58e5b759e03e574418f9171e',
#     'name': 'Pizzeria Che Si Mangia',
#     'location': {'address': 'Via Frassinago, 5',
#      'lat': 44.49364,
#      'lng': 11.33289,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49364,
#        'lng': 11.33289}],
#      'distance': 805,
#      'postalCode': '40123',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Frassinago, 5',
#       '40123 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4d7a7de6e8b7a1cdbb2d991f',
#     'name': 'Ristorante Pizzeria il Saraceno',
#     'location': {'address': 'Via Calcavinazzi 2/D',
#      'lat': 44.49544147392279,
#      'lng': 11.340604909441515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49544147392279,
#        'lng': 11.340604909441515}],
#      'distance': 275,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Calcavinazzi 2/D', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4cb4cddc56fca1cd135e4a18',
#     'name': 'Pizzeria il Portico',
#     'location': {'address': 'Strada Maggiore 53/c',
#      'lat': 44.49089175777167,
#      'lng': 11.355485457056918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49089175777167,
#        'lng': 11.355485457056918}],
#      'distance': 1035,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Strada Maggiore 53/c', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e63ccb3b61cd780892535e0',
#     'name': 'Pizzeria elena',
#     'location': {'address': 'Via arienti 7',
#      'lat': 44.487312361063886,
#      'lng': 11.348316152347413,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.487312361063886,
#        'lng': 11.348316152347413}],
#      'distance': 822,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via arienti 7', 'Bologna Emilia-Romagna']},
#     'categories': [],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '517053dde4b0966550268ef4',
#     'name': 'Pizzeria Casa',
#     'location': {'address': 'Via Delle Belle Arti',
#      'lat': 44.49530148918131,
#      'lng': 11.353471025952647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49530148918131,
#        'lng': 11.353471025952647}],
#      'distance': 848,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Delle Belle Arti', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c594c664ed9ef3b3db0d96d',
#     'name': "Pizzeria dell'Eden",
#     'location': {'address': 'Via Irnerio 23',
#      'lat': 44.49987246842047,
#      'lng': 11.34939193725586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49987246842047,
#        'lng': 11.34939193725586}],
#      'distance': 855,
#      'postalCode': '40126',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Irnerio 23', '40126 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '5545ffc1498e6091e218223e',
#     'name': 'Pizzeria Vecchia Malga Famiglia Chiari',
#     'location': {'address': 'Aeroporto Di Bologna',
#      'lat': 44.52934395635153,
#      'lng': 11.292690775916121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.52934395635153,
#        'lng': 11.292690775916121}],
#      'distance': 5633,
#      'cc': 'IT',
#      'neighborhood': 'Borgo Panigale',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Aeroporto Di Bologna', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4cb5a6d27abcbfb727faa51f',
#     'name': 'Pizzeria La Pantera Rosa Sprint',
#     'location': {'address': 'Via Levanti, 8/D',
#      'lat': 44.49541,
#      'lng': 11.38656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49541,
#        'lng': 11.38656}],
#      'distance': 3461,
#      'postalCode': '40138',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Levanti, 8/D', '40138 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c9ddaeb0e9bb1f77224e15f',
#     'name': 'Pizzeria Marconi',
#     'location': {'address': 'via Marconi',
#      'lat': 44.50041138008259,
#      'lng': 11.339197108005996,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.50041138008259,
#        'lng': 11.339197108005996}],
#      'distance': 809,
#      'postalCode': '40122',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['via Marconi', '40122 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4de4ce5bb0fb267148bc48e6',
#     'name': 'Pizzeria Due Torri 2',
#     'location': {'address': 'via Saragozza 55/A',
#      'lat': 44.490025630000005,
#      'lng': 11.333229049999998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.490025630000005,
#        'lng': 11.333229049999998}],
#      'distance': 878,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['via Saragozza 55/A', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e8de873b8f71a700b4f6e2f',
#     'name': 'BarbPizzeria Aldrovandi',
#     'location': {'lat': 44.49378772928239,
#      'lng': 11.351938345815253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.49378772928239,
#        'lng': 11.351938345815253}],
#      'distance': 707,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e57f45cd22d61e8f341d928',
#     'name': 'Pizzeria da Antonello - Drago Verde',
#     'location': {'lat': 44.46766203448776,
#      'lng': 11.370913956828247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.46766203448776,
#        'lng': 11.370913956828247}],
#      'distance': 3645,
#      'cc': 'IT',
#      'neighborhood': 'Savena',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4e9339499a521f515fe74fac',
#     'name': 'Pizzeria Pantera Rosa',
#     'location': {'address': 'Via Francesco Zanardi, 189/D',
#      'lat': 44.52267,
#      'lng': 11.31991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.52267,
#        'lng': 11.31991}],
#      'distance': 3713,
#      'postalCode': '40131',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Francesco Zanardi, 189/D',
#       '40131 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '5205428111d2aadc55629338',
#     'name': 'Pizzeria Da Carlo',
#     'location': {'address': 'Via S. Petronio Vecchio, 43',
#      'crossStreet': 'Porta Ravegnana',
#      'lat': 44.489327,
#      'lng': 11.353973,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.489327,
#        'lng': 11.353973}],
#      'distance': 994,
#      'postalCode': '40131',
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via S. Petronio Vecchio, 43 (Porta Ravegnana)',
#       '40131 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4d8cebdb1716a14322d80bf7',
#     'name': 'Mimì Ristorante Pizzeria',
#     'location': {'address': 'Via Mengoli, 30/D',
#      'crossStreet': 'Via Vizzani',
#      'lat': 44.48977,
#      'lng': 11.37191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.48977,
#        'lng': 11.37191}],
#      'distance': 2333,
#      'postalCode': '40138',
#      'cc': 'IT',
#      'neighborhood': 'San Vitale',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Mengoli, 30/D (Via Vizzani)',
#       '40138 Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '126282018'},
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c8bcfe6509e3704e3682d55',
#     'name': 'Pizzeria Nosadella',
#     'location': {'lat': 44.490611,
#      'lng': 11.331242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.490611,
#        'lng': 11.331242}],
#      'distance': 996,
#      'cc': 'IT',
#      'country': 'Italia'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '4c6ecaca06ed6dcb26c7a722',
#     'name': 'Ristorante Pizzeria Tenerife',
#     'location': {'address': 'Via Salvini, 12/B',
#      'lat': 44.5047239638399,
#      'lng': 11.366457167235492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.5047239638399,
#        'lng': 11.366457167235492}],
#      'distance': 2229,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Salvini, 12/B', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False},
#    {'id': '53905bd5498e21833a53303e',
#     'name': 'Pizzeria Saragozza 55',
#     'location': {'address': 'Via Saragozza, 55A',
#      'lat': 44.491758,
#      'lng': 11.329867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.491758,
#        'lng': 11.329867}],
#      'distance': 1067,
#      'cc': 'IT',
#      'city': 'Bologna',
#      'state': 'Emilia-Romagna',
#      'country': 'Italia',
#      'formattedAddress': ['Via Saragozza, 55A', 'Bologna Emilia-Romagna']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607246772',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\Users\Matteo\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                 name  \
# 0  4bfcfc65e529c928f231ba8c     Pizzeria Ristorante Scalinatella
# 1  4de8c676fa76fd1168a7f79b        Trattoria Pizzeria Belle Arti
# 2  4bebda0da9900f47b0381840                     Pizzeria Petroni
# 3  4c1e6035c4a0ef3b6f1cbd8b                     Pizzeria da Totò
# 4  4c6d7fa7d5c3a1cdbfa7c52b  Ristorante Pizzeria Porta Saragozza
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1607246772    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1607246772    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1607246772    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1607246772    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1607246772    False
#
#                location.address  location.lat  location.lng  \
# 0  Via Caduti di Cefalonia, 5/E     44.495250     11.344260
# 1      Via delle Belle Arti, 14     44.497805     11.349946
# 2               Via Petroni 7/b     44.494699     11.352031
# 3               Via San Rocco 7     44.496403     11.330180
# 4              Via Saragozza 71     44.490558     11.331225
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 44.49525, 'lng': ...                200
# 1  [{'label': 'display', 'lat': 44.49780496606923...                716
# 2  [{'label': 'display', 'lat': 44.49469924095751...                723
# 3  [{'label': 'display', 'lat': 44.49640345447888...               1065
# 4  [{'label': 'display', 'lat': 44.49055832487309...                999
#
#   location.postalCode location.cc location.city  location.state  \
# 0               40125          IT       Bologna  Emilia-Romagna
# 1               40126          IT       Bologna  Emilia-Romagna
# 2               40126          IT       Bologna  Emilia-Romagna
# 3               40122          IT       Bologna  Emilia-Romagna
# 4               40123          IT       Bologna  Emilia-Romagna
#
#   location.country                          location.formattedAddress  \
# 0           Italia  [Via Caduti di Cefalonia, 5/E, 40125 Bologna E...
# 1           Italia  [Via delle Belle Arti, 14, 40126 Bologna Emili...
# 2           Italia    [Via Petroni 7/b, 40126 Bologna Emilia-Romagna]
# 3           Italia    [Via San Rocco 7, 40122 Bologna Emilia-Romagna]
# 4           Italia   [Via Saragozza 71, 40123 Bologna Emilia-Romagna]
#
#   location.crossStreet location.neighborhood venuePage.id
# 0                  NaN                   NaN          NaN
# 1                  NaN                   NaN          NaN
# 2                  NaN                   NaN          NaN
# 3                  NaN                   NaN          NaN
# 4                  NaN                   NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                
# 7                 Via del Timavo  44.501957  11.318903
# 8           Via Andrea Costa 114  44.495210  11.318464
# 9              Strada Maggiore 3  44.494044  11.346955
# 10          Piazza S. Martino 3b  44.497171  11.346353
# 11            Via Galliera, 12 c  44.498382  11.342100
# 12          Via Nazario Sauro 28  44.497957  11.339596
# 13        Via dei castagnoli 6/B  44.496278  11.349222
# 14                 Via Ferrarese  44.513788  11.352389
# 15              Via Petroni 29/A  44.495607  11.350040
# 16             Via Nosadella 14A  44.492203  11.335415
# 17                           NaN  44.492209  11.335207
# 18                           NaN  44.497231  11.349003
# 19            Via zamboni 26 E F  44.496263  11.350578
# 20              Via delle Moline  44.497316  11.349272
# 21                           NaN  44.518228  11.324174
# 22                           NaN  44.499508  11.346359
# 23                           NaN  44.499126  11.342956
# 24                           NaN  44.487585  11.348138
# 25     Via Giuseppe Mazzini, 170  44.484815  11.371690
# 26               Via Casoni, 2/b  44.520412  11.360477
# 27              Via Mascarella 9  44.498403  11.349478
# 28                           NaN  44.498408  11.343638
# 29                Via San Vitale  44.494442  11.349379
# 30                           NaN  44.497101  11.336588
# 31           Via Calcavinazzi, 2  44.495490  11.340660
# 32             Via Frassinago, 5  44.493640  11.332890
# 33          Via Calcavinazzi 2/D  44.495441  11.340605
# 34          Strada Maggiore 53/c  44.490892  11.355485
# 35                 Via arienti 7  44.487312  11.348316
# 36          Via Delle Belle Arti  44.495301  11.353471
# 37                Via Irnerio 23  44.499872  11.349392
# 38          Aeroporto Di Bologna  44.529344  11.292691
# 39              Via Levanti, 8/D  44.495410  11.386560
# 40                   via Marconi  44.500411  11.339197
# 41            via Saragozza 55/A  44.490026  11.333229
# 42                           NaN  44.493788  11.351938
# 43                           NaN  44.467662  11.370914
# 44  Via Francesco Zanardi, 189/D  44.522670  11.319910
# 45   Via S. Petronio Vecchio, 43  44.489327  11.353973
# 46             Via Mengoli, 30/D  44.489770  11.371910
# 47                           NaN  44.490611  11.331242
# 48             Via Salvini, 12/B  44.504724  11.366457
# 49            Via Saragozza, 55A  44.491758  11.329867
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 44.49525, 'lng': ...       200      40125
# 1   [{'label': 'display', 'lat': 44.49780496606923...       716      40126
# 2   [{'label': 'display', 'lat': 44.49469924095751...       723      40126
# 3   [{'label': 'display', 'lat': 44.49640345447888...      1065      40122
# 4   [{'label': 'display', 'lat': 44.49055832487309...       999      40123
# 5   [{'label': 'display', 'lat': 44.49496056964607...       158        NaN
# 6   [{'label': 'display', 'lat': 44.494838, 'lng':...      2139        NaN
# 7   [{'label': 'display', 'lat': 44.50195744687222...      2126      40133
# 8   [{'label': 'display', 'lat': 44.49520951404032...      1958      40134
# 9   [{'label': 'display', 'lat': 44.49404434994599...       314      40125
# 10  [{'label': 'display', 'lat': 44.497171, 'lng':...       470      40126
# 11  [{'label': 'display', 'lat': 44.498382, 'lng':...       529        NaN
# 12  [{'label': 'display', 'lat': 44.497957, 'lng':...       549        NaN
# 13  [{'label': 'display', 'lat': 44.49627750753935...       570        NaN
# 14  [{'label': 'display', 'lat': 44.513788, 'lng':...      2359        NaN
# 15  [{'label': 'display', 'lat': 44.49560661431662...       596        NaN
# 16  [{'label': 'display', 'lat': 44.49220275878906...       626        NaN
# 17  [{'label': 'display', 'lat': 44.492209, 'lng':...       642        NaN
# 18  [{'label': 'display', 'lat': 44.497231, 'lng':...       617        NaN
# 19  [{'label': 'display', 'lat': 44.496263, 'lng':...       664        NaN
# 20  [{'label': 'display', 'lat': 44.497316, 'lng':...       640        NaN
# 21  [{'label': 'display', 'lat': 44.518228, 'lng':...      3116        NaN
# 22  [{'label': 'display', 'lat': 44.49950790405273...       701        NaN
# 23  [{'label': 'display', 'lat': 44.49912626366037...       607        NaN
# 24  [{'label': 'display', 'lat': 44.48758473942497...       789        NaN
# 25  [{'label': 'display', 'lat': 44.48481518599252...      2479      40139
# 26  [{'label': 'display', 'lat': 44.52041244506836...      3283        NaN
# 27  [{'label': 'display', 'lat': 44.49840319604394...       734      40126
# 28  [{'label': 'display', 'lat': 44.49840796904334...       529        NaN
# 29  [{'label': 'display', 'lat': 44.49444228484714...       511        NaN
# 30  [{'label': 'display', 'lat': 44.49710142053445...       638        NaN
# 31  [{'label': 'display', 'lat': 44.49549, 'lng': ...       276      40121
# 32  [{'label': 'display', 'lat': 44.49364, 'lng': ...       805      40123
# 33  [{'label': 'display', 'lat': 44.49544147392279...       275        NaN
# 34  [{'label': 'display', 'lat': 44.49089175777167...      1035        NaN
# 35  [{'label': 'display', 'lat': 44.48731236106388...       822        NaN
# 36  [{'label': 'display', 'lat': 44.49530148918131...       848        NaN
# 37  [{'label': 'display', 'lat': 44.49987246842047...       855      40126
# 38  [{'label': 'display', 'lat': 44.52934395635153...      5633        NaN
# 39  [{'label': 'display', 'lat': 44.49541, 'lng': ...      3461      40138
# 40  [{'label': 'display', 'lat': 44.50041138008259...       809      40122
# 41  [{'label': 'display', 'lat': 44.49002563000000...       878        NaN
# 42  [{'label': 'display', 'lat': 44.49378772928239...       707        NaN
# 43  [{'label': 'display', 'lat': 44.46766203448776...      3645        NaN
# 44  [{'label': 'display', 'lat': 44.52267, 'lng': ...      3713      40131
# 45  [{'label': 'display', 'lat': 44.489327, 'lng':...       994      40131
# 46  [{'label': 'display', 'lat': 44.48977, 'lng': ...      2333      40138
# 47  [{'label': 'display', 'lat': 44.490611, 'lng':...       996        NaN
# 48  [{'label': 'display', 'lat': 44.5047239638399,...      2229        NaN
# 49  [{'label': 'display', 'lat': 44.491758, 'lng':...      1067        NaN
#
#     cc     city           state country  \
# 0   IT  Bologna  Emilia-Romagna  Italia
# 1   IT  Bologna  Emilia-Romagna  Italia
# 2   IT  Bologna  Emilia-Romagna  Italia
# 3   IT  Bologna  Emilia-Romagna  Italia
# 4   IT  Bologna  Emilia-Romagna  Italia
# 5   IT  Bologna  Emilia-Romagna  Italia
# 6   IT  Bologna  Emilia-Romagna  Italia
# 7   IT  Bologna  Emilia-Romagna  Italia
# 8   IT  Bologna  Emilia-Romagna  Italia
 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19       [Via zamboni 26 E F, Bologna Emilia-Romagna]                 NaN
# 20                                 [Via delle Moline]                 NaN
# 21                           [Bologna Emilia-Romagna]                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
# 24                                                NaN                 NaN
# 25  [Via Giuseppe Mazzini, 170, 40139 Bologna Emil...                 NaN
# 26          [Via Casoni, 2/b, Bologna Emilia-Romagna]                 NaN
# 27   [Via Mascarella 9, 40126 Bologna Emilia-Romagna]                 NaN
# 28                                                NaN                 NaN
# 29           [Via San Vitale, Bologna Emilia-Romagna]                 NaN
# 30                                                NaN                 NaN
# 31  [Via Calcavinazzi, 2, 40121 Bologna Emilia-Rom...                 NaN
# 32  [Via Frassinago, 5, 40123 Bologna Emilia-Romagna]                 NaN
# 33     [Via Calcavinazzi 2/D, Bologna Emilia-Romagna]                 NaN
# 34     [Strada Maggiore 53/c, Bologna Emilia-Romagna]                 NaN
# 35            [Via arienti 7, Bologna Emilia-Romagna]                 NaN
# 36     [Via Delle Belle Arti, Bologna Emilia-Romagna]                 NaN
# 37     [Via Irnerio 23, 40126 Bologna Emilia-Romagna]                 NaN
# 38     [Aeroporto Di Bologna, Bologna Emilia-Romagna]                 NaN
# 39   [Via Levanti, 8/D, 40138 Bologna Emilia-Romagna]                 NaN
# 40        [via Marconi, 40122 Bologna Emilia-Romagna]                 NaN
# 41       [via Saragozza 55/A, Bologna Emilia-Romagna]                 NaN
# 42                                                NaN                 NaN
# 43                                                NaN                 NaN
# 44  [Via Francesco Zanardi, 189/D, 40131 Bologna E...                 NaN
# 45  [Via S. Petronio Vecchio, 43 (Porta Ravegnana)...     Porta Ravegnana
# 46  [Via Mengoli, 30/D (Via Vizzani), 40138 Bologn...         Via Vizzani
# 47                                                NaN                 NaN
# 48        [Via Salvini, 12/B, Bologna Emilia-Romagna]                 NaN
# 49       [Via Saragozza, 55A, Bologna Emilia-Romagna]                 NaN
#
#       neighborhood                        id
# 0              NaN  4bfcfc65e529c928f231ba8c
# 1              NaN  4de8c676fa76fd1168a7f79b
# 2              NaN  4bebda0da9900f47b0381840
# 3              NaN  4c1e6035c4a0ef3b6f1cbd8b
# 4              NaN  4c6d7fa7d5c3a1cdbfa7c52b
# 5              NaN  50a62f8ee4b06c2ca79bd604
# 6              NaN  5339c0e811d25f69b458d977
# 7              NaN  4e3d82b7fa76455375b8de0f
# 8              NaN  4cc410e542d1b60c8c521b13
# 9              NaN  4cadad6655238cfa0564b3fb
# 10             NaN  5d9c72906b85670008db520e
# 11             NaN  4db5c2ec0cb6729b6aabf2c3
# 12             NaN  533ab0a1498e11c874ef2ffc
# 13             NaN  4d91c3b0d7b1236af4e63638
# 14          Navile  4c4eb9149932e21ea14532ce
# 15             NaN  4f2145b1e4b07fb248d74896
# 16             NaN  4e3ed4e5ae6045423677c320
# 17             NaN  51ba0f81498eb59c5e9e25b7
# 18             NaN  4ffca8d1e4b07010bfa9c0a2
# 19             NaN  4c56627b744a0f4753b5c6cb
# 20             NaN  51dd42db498ec99902ecc04c
# 21          Navile  4dea06f052b11677f02ff4e4
# 22             NaN  50bcfa64e4b0073c180fae90
# 23             NaN  51325aa3e4b0a2e12a780120
# 24             NaN  4c42123c520fa59391a4caac
# 25             NaN  4c9c5513e9a7ef3ba7843316
# 26             NaN  52fe72bd498efa6404b763e0
# 27             NaN  4e1a0dd3d4c062b044f7d335
# 28             NaN  526bfdcc498e90936fa7f084
# 29             NaN  4cd5bef276ab721e2b206f6a
# 30             NaN  4d851c6e5e70224ba4d91b09
# 31             NaN  5984c0fba5a31517f8ac69c1
# 32             NaN  58e5b759e03e574418f9171e
# 33             NaN  4d7a7de6e8b7a1cdbb2d991f
# 34             NaN  4cb4cddc56fca1cd135e4a18
# 35             NaN  4e63ccb3b61cd780892535e0
# 36             NaN  517053dde4b0966550268ef4
# 37             NaN  4c594c664ed9ef3b3db0d96d
# 38  Borgo Panigale  5545ffc1498e6091e218223e
# 39             NaN  4cb5a6d27abcbfb727faa51f
# 40             NaN  4c9ddaeb0e9bb1f77224e15f
# 41             NaN  4de4ce5bb0fb267148bc48e6
# 42             NaN  4e8de873b8f71a700b4f6e2f
# 43          Savena  4e57f45cd22d61e8f341d928
# 44             NaN  4e9339499a521f515fe74fac
# 45             NaN  5205428111d2aadc55629338
# 46      San Vitale  4d8cebdb1716a14322d80bf7
# 47             NaN  4c8bcfe6509e3704e3682d55
# 48             NaN  4c6ecaca06ed6dcb26c7a722
# 49             NaN  53905bd5498e21833a53303e

# %% [raw]
# Inspecting the name of the dataframe_filtered

# %%
dataframe_filtered.name
# Out:
# 0           Pizzeria Ristorante Scalinatella
# 1              Trattoria Pizzeria Belle Arti
# 2                           Pizzeria Petroni
# 3                           Pizzeria da Totò
# 4        Ristorante Pizzeria Porta Saragozza
# 5                           Pizzeria Nettuno
# 6                        pizzeria a modo mio
# 7                          Pizzeria Da Carlo
# 8                     Pizzeria al Tavolaccio
# 9                         Pizzeria Due Torri
# 10              L’Antica Pizzeria Da Michele
# 11                 Pizzeria D'asporto Stella
# 12                       Pizzeria da Roberto
# 13                         Pizzeria Respighi
# 14               Ristorante Pizzeria Rococo'
# 15                         Pizzeria Pugliese
# 16                    Pizzeria da asporto GM
# 17                               Pizzeria GM
# 18                            Pizzeria D.O.C
# 19                           Pizzeria Emilia
# 20                              Pizzeria DOC
# 21                       Pizzeria La Livella
# 22                        pizzeria gli archi
# 23                  Pizzeria Il Moro Bologna
# 24                      Pizzeria O' Sole Mio
# 25                         Pizzeria Pinterrè
# 26                           Pizzeria Naveed
# 27             Pizzeria d'asporto Mascarella
# 28                           Altero Pizzeria
# 29              Pizzeria Ristorante La Brace
# 30                       Pizzeria Il Sorriso
# 31           Il Saraceno Ristorante Pizzeria
# 32                    Pizzeria Che Si Mangia
# 33           Ristorante Pizzeria il Saraceno
# 34                       Pizzeria il Portico
# 35                            Pizzeria elena
# 36                             Pizzeria Casa
# 37                        Pizzeria dell'Eden
# 38    Pizzeria Vecchia Malga Famiglia Chiari
# 39           Pizzeria La Pantera Rosa Sprint
# 40                          Pizzeria Marconi
# 41                      Pizzeria Due Torri 2
# 42                   BarbPizzeria Aldrovandi
# 43       Pizzeria da Antonello - Drago Verde
# 44                     Pizzeria Pantera Rosa
# 45                         Pizzeria Da Carlo
# 46                  Mimì Ristorante Pizzeria
# 47                        Pizzeria Nosadella
# 48              Ristorante Pizzeria Tenerife
# 49                     Pizzeria Saragozza 55
# Name: name, dtype: object

# %% [raw]
# We are going to filter again the original dataframe getting only few features: Name of pizzerias, Category, the address and the latitude and longitude

# %%
dataframe_filtered = dataframe_filtered[['name',	'categories',	'address',	'lat',	'lng']]
dataframe_filtered
# Out:
#                                       name          categories  \
# 0         Pizzeria Ristorante Scalinatella  Italian Restaurant
# 1            Trattoria Pizzeria Belle Arti         Pizza Place
# 2                         Pizzeria Petroni         Pizza Place
# 3                         Pizzeria da Totò         Pizza Place
# 4      Ristorante Pizzeria Porta Saragozza  Italian Restaurant
# 5                         Pizzeria Nettuno         Pizza Place
# 6                      pizzeria a modo mio         Pizza Place
# 7                        Pizzeria Da Carlo         Pizza Place
# 8                   Pizzeria al Tavolaccio         Pizza Place
# 9                       Pizzeria Due Torri         Pizza Place
# 10            L’Antica Pizzeria Da Michele         Pizza Place
# 11               Pizzeria D'asporto Stella         Pizza Place
# 12                     Pizzeria da Roberto         Pizza Place
# 13                       Pizzeria Respighi         Pizza Place
# 14             Ristorante Pizzeria Rococo'         Pizza Place
# 15                       Pizzeria Pugliese         Pizza Place
# 16                  Pizzeria da asporto GM         Pizza Place
# 17                             Pizzeria GM         Pizza Place
# 18                          Pizzeria D.O.C          Food Court
# 19                         Pizzeria Emilia                 Bar
# 20                            Pizzeria DOC         Pizza Place
# 21                     Pizzeria La Livella         Pizza Place
# 22                      pizzeria gli archi         Pizza Place
# 23                Pizzeria Il Moro Bologna         Pizza Place
# 24                    Pizzeria O' Sole Mio         Pizza Place
# 25                       Pizzeria Pinterrè         Pizza Place
# 26                         Pizzeria Naveed         Pizza Place
# 27           Pizzeria d'asporto Mascarella         Pizza Place
# 28                         Altero Pizzeria         Pizza Place
# 29            Pizzeria Ristorante La Brace         Pizza Place
# 30                     Pizzeria Il Sorriso         Pizza Place
# 31         Il Saraceno Ristorante Pizzeria         Event Space
# 32                  Pizzeria Che Si Mangia         Pizza Place
# 33         Ristorante Pizzeria il Saraceno         Pizza Place
# 34                     Pizzeria il Portico         Pizza Place
# 35                          Pizzeria elena                None
# 36                           Pizzeria Casa         Pizza Place
# 37                      Pizzeria dell'Eden         Pizza Place
# 38  Pizzeria Vecchia Malga Famiglia Chiari  Italian Restaurant
# 39         Pizzeria La Pantera Rosa Sprint         Pizza Place
# 40                        Pizzeria Marconi         Pizza Place
# 41                    Pizzeria Due Torri 2         Pizza Place
